# %%
#Imports
import pandas as pd
import numpy as np
import statistics
from sklearn.impute import SimpleImputer
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler

# %%
imputer = SimpleImputer(strategy='median')
scaler = StandardScaler()

num_pipeline = Pipeline([
        ('imputer', imputer),
        ('std_scaler', scaler),
    ]) #Pipeline for numerical features

def process_data(data_input):
    
    catergorical_labels = "name" 
    num_attribs = data_input.drop(catergorical_labels, axis=1) #Use only numerical features
  
    return num_pipeline.fit_transform(num_attribs)

# %%
#Reading the data
data = pd.read_excel("database_2.xlsx")
data
# Out:
#      playerId             teamName   playedPositions positionText    rating  \
# 0      279575             Flamengo  -AMC-AML-AMR-FW-      Forward  7.400833
# 1       16886          Atletico MG  -AMC-AML-AMR-FW-      Forward  7.397143
# 2      318302  Red Bull Bragantino         -AML-AMR-      Forward  7.256000
# 3      356785           America MG         -AMC-AMR-      Forward  7.247742
# 4      384431               Gremio         -AML-AMR-      Forward  7.155172
# ..        ...                  ...               ...          ...       ...
# 362    377097       Chapecoense AF              -MC-     Defender  6.160625
# 363     21613            Fortaleza          -AMR-FW-      Forward  6.158800
# 364    120762           America MG               NaN      Forward  6.135500
# 365    397825          Corinthians             -DMC-   Midfielder  6.127500
# 366    397586            Juventude               NaN      Forward  6.061250
#
#      totalPassesPerGame  accurateCrossesPerGame  accurateCrossesPerGame.1  \
# 0             22.875000                0.041667                  0.041667
# 1             23.685714                0.171429                  0.171429
# 2             30.566667                1.333333                  1.333333
# 3             22.709677                0.870968                  0.870968
# 4             31.862069                0.517241                  0.517241
# ..                  ...                     ...                       ...
# 362           12.937500                0.125000                  0.125000
# 363            5.760000                0.080000                  0.080000
# 364            8.050000                0.250000                  0.250000
# 365           11.562500                0.000000                  0.000000
# 366            2.937500                0.312500                  0.312500
#
#      accurateLongPassPerGame  accurateThroughBallPerGame  ...  tacklePerGame  \
# 0                   0.291667                    0.125000  ...       0.750000
# 1                   0.800000                    0.028571  ...       0.342857
# 2                   2.200000                    0.100000  ...       0.500000
# 3                   0.870968                    0.193548  ...       0.870968
# 4                   0.827586                    0.103448  ...       1.068966
# ..                       ...                         ...  ...            ...
# 362                 0.687500                    0.000000  ...       0.750000
# 363                 0.160000                    0.040000  ...       0.280000
# 364                 0.350000                    0.000000  ...       0.500000
# 365                 0.437500                    0.000000  ...       0.312500
# 366                 0.125000                    0.000000  ...       0.187500
#
#     interceptionPerGame  foulsPerGame  offsideWonPerGame  clearancePerGame  \
# 0              0.458333      1.750000           0.000000          1.000000
# 1              0.114286      1.542857           0.000000          0.571429
# 2              0.433333      0.600000           0.000000          0.266667
# 3              0.354839      0.903226           0.032258          0.225806
# 4              0.551724      0.517241           0.000000          0.275862
# ..                  ...           ...                ...               ...
# 362            0.562500      0.750000           0.000000          0.562500
# 363            0.080000      0.800000           0.040000          0.360000
# 364            0.250000      0.350000           0.000000          0.200000
# 365            0.125000      0.437500           0.062500          0.875000
# 366            0.062500      0.375000           0.000000          0.062500
#
#      wasDribbledPerGame  outfielderBlockPerGame  goalOwn  idade       valor
# 0              0.708333                0.041667        0     29  4,50 mi. €
# 1              0.428571                0.028571        0     33  2,50 mi. €
# 2              0.933333                0.200000        0     22  5,00 mi. €
# 3              1.064516                0.000000        0     25   700 mil €
# 4              1.137931                0.034483        0     22  7,50 mi. €
# ..                  ...                     ...      ...    ...         ...
# 362            0.312500                0.187500        0     22   300 mil €
# 363            0.280000                0.000000        0     36   500 mil €
# 364            0.150000                0.000000        0     37   250 mil €
# 365            0.312500                0.312500        0     20   800 mil €
# 366            0.125000                0.000000        0     21   700 mil €
#
# [367 rows x 34 columns]

# %%
#Data cleaning
def set_value(value):
    number, unit, _ = value.split(" ")
    number = float(number.replace(",","."))
    unit = 10e5 if unit == "mi." else 10e2
    return number*unit

data["valor"] = [set_value(valor) for valor in data["valor"]]

# %%
cleaned_data = data.drop(['playerId', 'teamName', 'playedPositions', 'positionText', "valor", 'idade'], axis=1)
cleaned_data = cleaned_data.reset_index().drop("index", axis=1)
cleaned_data
# Out:
#        rating  totalPassesPerGame  accurateCrossesPerGame  \
# 0    7.400833           22.875000                0.041667
# 1    7.397143           23.685714                0.171429
# 2    7.256000           30.566667                1.333333
# 3    7.247742           22.709677                0.870968
# 4    7.155172           31.862069                0.517241
# ..        ...                 ...                     ...
# 362  6.160625           12.937500                0.125000
# 363  6.158800            5.760000                0.080000
# 364  6.135500            8.050000                0.250000
# 365  6.127500           11.562500                0.000000
# 366  6.061250            2.937500                0.312500
#
#      accurateCrossesPerGame.1  accurateLongPassPerGame  \
# 0                    0.041667                 0.291667
# 1                    0.171429                 0.800000
# 2                    1.333333                 2.200000
# 3                    0.870968                 0.870968
# 4                    0.517241                 0.827586
# ..                        ...                      ...
# 362                  0.125000                 0.687500
# 363                  0.080000                 0.160000
# 364                  0.250000                 0.350000
# 365                  0.000000                 0.437500
# 366                  0.312500                 0.125000
#
#      accurateThroughBallPerGame  passSuccess                 name  goal  \
# 0                      0.125000    74.499089       Bruno Henrique    11
# 1                      0.028571    75.633293                 Hulk    19
# 2                      0.100000    81.897492                Artur    12
# 3                      0.193548    72.585227               Ademir    13
# 4                      0.103448    83.982684             Ferreira     3
# ..                          ...          ...                  ...   ...
# 362                    0.000000    79.710145                Ronei     0
# 363                    0.040000    65.277778  Wellington Paulista     3
# 364                    0.000000    78.260870    Marcelo Aparecido     0
# 365                    0.000000    82.162162               Xavier     0
# 366                    0.000000    70.212766     Fernando Pacheco     0
#
#      assistTotal  ...  subOn  minsPlayed  tacklePerGame  interceptionPerGame  \
# 0              5  ...      3        1905       0.750000             0.458333
# 1              7  ...      2        2931       0.342857             0.114286
# 2              8  ...      2        2497       0.500000             0.433333
# 3              3  ...      2        2573       0.870968             0.354839
# 4              6  ...      5        2141       1.068966             0.551724
# ..           ...  ...    ...         ...            ...                  ...
# 362            0  ...      8         722       0.750000             0.562500
# 363            0  ...     17         884       0.280000             0.080000
# 364            0  ...     16         382       0.500000             0.250000
# 365            0  ...     14         282       0.312500             0.125000
# 366            0  ...     16         221       0.187500             0.062500
#
#      foulsPerGame  offsideWonPerGame  clearancePerGame  wasDribbledPerGame  \
# 0        1.750000           0.000000          1.000000            0.708333
# 1        1.542857           0.000000          0.571429            0.428571
# 2        0.600000           0.000000          0.266667            0.933333
# 3        0.903226           0.032258          0.225806            1.064516
# 4        0.517241           0.000000          0.275862            1.137931
# ..            ...                ...               ...                 ...
# 362      0.750000           0.000000          0.562500            0.312500
# 363      0.800000           0.040000          0.360000            0.280000
# 364      0.350000           0.000000          0.200000            0.150000
# 365      0.437500           0.062500          0.875000            0.312500
# 366      0.375000           0.000000          0.062500            0.125000
#
#      outfielderBlockPerGame  goalOwn
# 0                  0.041667        0
# 1                  0.028571        0
# 2                  0.200000        0
# 3                  0.000000        0
# 4                  0.034483        0
# ..                      ...      ...
# 362                0.187500        0
# 363                0.000000        0
# 364                0.000000        0
# 365                0.312500        0
# 366                0.000000        0
#
# [367 rows x 28 columns]

# %%
#Data preprocess
prep_data = process_data(cleaned_data)
prep_data
# Out:
# array([[ 3.19274557, -0.4004632 , -0.67759817, ...,  0.14120987,
#         -0.63683477, -0.19009938],
#        [ 3.17709287, -0.34180155, -0.30561022, ..., -0.51907674,
#         -0.69128031, -0.19009938],
#        [ 2.57845278,  0.15609027,  3.02521768, ...,  0.6722489 ,
#          0.02146119, -0.19009938],
#        ...,
#        [-2.17401025, -1.47317026, -0.08036981, ..., -1.17655363,
#         -0.81007055, -0.19009938],
#        [-2.20794126, -1.21901285, -0.79704385, ..., -0.79302544,
#          0.48919779, -0.19009938],
#        [-2.4889325 , -1.84310044,  0.0987987 , ..., -1.23555796,
#         -0.81007055, -0.19009938]])

# %%
#SVD
u, s, vt = np.linalg.svd(prep_data, full_matrices=False)

# %%
ut = u[:,:5] #Selecting 5 most "relevant" columns
ut = ut / np.linalg.norm(ut, axis =1).reshape(-1,1) #Normalizing 
products = ut.dot(ut.transpose()) #Matrix containing player similarity probability

# %%
products.shape #Checking shape
# Out:
# (367, 367)

# %%
#Testing
index = cleaned_data.index #Players index

# %%
def get_smilar_players_ordered_by_value(player_name, similar_players_number):
    
    player_index = index[cleaned_data["name"] == player_name][0] #Index of the player to be compared
    
    player_similarity_row = products[player_index] #Player similarity vector
    
    selection_value = -1 * (similar_players_number + 1)
    similar_player_index = np.argpartition(player_similarity_row, selection_value)[selection_value:] #Selecting B most similar players, including the given one
    similar_player_index_no_main = similar_player_index[similar_player_index != player_index] #Similar player without the given one
    mean_value = statistics.mean(data.iloc[similar_player_index]["valor"]) #Mean value of similar players including given one
    mean_age = statistics.mean(data.iloc[similar_player_index]["idade"]) #Mean age of similar players including given one
    mean_age_value = mean_age * mean_value
    
    return pd.DataFrame( \
        sorted(
            [ \
                [player["name"], player["teamName"], player["idade"], player["valor"]/10e2, round((1 - (player["valor"] * player["idade"] / mean_age_value))*100, 2)]  
            for idx, player in data.iloc[similar_player_index_no_main].iterrows()], \
        key=lambda x: x[4], reverse=True), \
    columns=["Name", "Team", "Age", "Value (TEUR)", "Possible gain %"]) #Returns the difference between similar player's value and their mean (including the given one)

# %%
get_smilar_players_ordered_by_value("Weverton", 10)
# Out:
#              Name                  Team  Age  Value (TEUR)  Possible gain %
# 0         Keiller        Chapecoense AF   23          50.0            96.87
# 1          Daniel         Internacional   26          50.0            96.46
# 2   Marcelo Boeck             Fortaleza   35         200.0            80.94
# 3  Gabriel Grando                Gremio   20         400.0            78.21
# 4    Felipe Alves             Fortaleza   32         650.0            43.35
# 5   Marcelo Carné             Juventude   30         900.0            26.47
# 6      João Paulo        Chapecoense AF   25        1400.0             4.68
# 7         Richard                 Ceara   26        1500.0            -6.21
# 8     Diego Alves              Flamengo   35        1500.0           -42.97
# 9          Santos  Athletico Paranaense   30        2500.0          -104.25
